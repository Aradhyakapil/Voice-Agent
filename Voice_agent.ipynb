# %% [markdown]
# <a href="https://colab.research.google.com/github/Aradhyakapil/Voice-Agent/blob/main/Voice_agent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai elevenlabs sounddevice scipy numpy git+https://github.com/openai/whisper.git

# %%
import openai
import whisper
from elevenlabs.client import ElevenLabs
from elevenlabs import play
from google.colab import files
from IPython.display import Audio, display

# Replace with your own keys
openai.api_key = "sk-"
tts = ElevenLabs(api_key="")

# Load Whisper model (this may take a minute)
model = whisper.load_model("base")

# ─── 2. Loop: upload → transcribe → chat → speak ───────────────────────────
while True:
    print("🔽 Please upload a WAV file (or name it ‘exit.wav’ to stop):")
    uploaded = files.upload()                   # opens file picker
    fname = next(iter(uploaded.keys()))

    # Exit condition
    if fname.lower().startswith("exit"):
        print("👋 Exiting.")
        break

    # 2.1 Transcribe with Whisper
    result = model.transcribe(fname)
    prompt = result["text"].strip()
    print(f"🧑 You said: {prompt}")

    # 2.2 Query GPT-4o-mini
    resp = openai.chat.completions.create(
        model="gpt-4o",
        messages=[{"role":"user","content":prompt}]
    )
    reply = resp.choices[0].message.content.strip()
    print(f"🤖 GPT-4o-mini: {reply}")

    # 2.3 Convert reply to speech & play
    audio = tts.text_to_speech.convert(
        text=reply,
        voice_id="21m00Tcm4TlvDq8ikWAM",              # or specific voice_id from voices list
        model_id="eleven_monolingual_v1",
        output_format="mp3_44100_32",   # choose desired output format
    )
    audio_bytes = b"".join(audio)

    # 🔊 Play in Colab
    display(Audio(audio_bytes, autoplay=True))
# Out:
# 🔽 Please upload a WAV file (or name it ‘exit.wav’ to stop):
#      <input type="file" id="files-223a25f1-4752-48be-9319-4ded506ca5c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-223a25f1-4752-48be-9319-4ded506ca5c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# ...
